# %% [markdown]
# # Pokemon Data Analysis
# ---

# %% [markdown]
# ## Importing Required Modules
# 1. importing numpy for mathematical operation on arrays and dataframe.
# 2. importing pandas for reading data and data manipualtion.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading dataaset

# %%
df=pd.read_csv('pokemon.csv')

# %%
df.head() ### viewing the data
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.shape
# Out:
# (800, 12)

# %% [markdown]
# ## To read 10 rows from starting

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %% [markdown]
# ## To read last 5 rows

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# ### Short Description abot the Dataset
# - Pokedex entry number of the Pokemon
#
# pokedex is an  catalog that provide information regarding the various species of Pokémon featured in the Pokémon video game, anime and manga series.)
# - Name = name of the Pokemon
# - Type 1 = each Pokemon has a type, this determines weakness/resistance to attacks [referred to as the primary type]
# - Type 2 = some Pokemon are dual type and have 2 [referred to as the secondary type]
# - HP = hit points, or health, defines how much damage a Pokemon can withstand before fainting
# - Attack =  the base modifier for normal attacks
# - Defense = the base damage resistance against normal attacks
# - Sp. Atk = special attack, the base modifier for special attacks
# - Sp. Def = the base damage resistance against special attacks
# - Speed = determines which Pokemon attacks first each round
# - Generation = refers to which grouping/game series the Pokemon was released in
# - Legendary = a boolean that identifies whether the Pokemon is legendary

# %% [markdown]
# ## To check the rows and columns in a data

# %%
df.shape
# Out:
# (800, 12)

# %% [markdown]
# ## To see all the columns in a data

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ## To check the datatypes of a column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      359 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# ## statistical summary

# %%
df.describe().T # numeric cols
# Out:
#             count       mean         std   min     25%    50%     75%    max
# #           800.0  362.81375  208.343798   1.0  184.75  364.5  539.25  721.0
# HP          800.0   69.25875   25.534669   1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366   5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501   5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294  10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916  20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474   5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290   1.0    2.00    3.0    5.00    6.0

# %%
df.describe(include='object') # non numeric
# Out:
#              Name Type 1  Type 2
# count         800    800     359
# unique        800     18      18
# top     Bulbasaur  Water  Flying
# freq            1    112      81

# %% [markdown]
# ### from this we can say that type 2 has null values as it has 359 enteries.
#
# top depicts : most frquent values
# the top of name columns ca be any as it  has all unique enteries.

# %%
df["Type 2"].mode()
# Out:
# 0    Flying
# Name: Type 2, dtype: object

# %% [markdown]
# ## To check the missing values in data

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        441
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# ## to see missing values %

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# #              0.000
# Name           0.000
# Type 1         0.000
# Type 2        55.125
# HP             0.000
# Attack         0.000
# Defense        0.000
# Sp. Atk        0.000
# Sp. Def        0.000
# Speed          0.000
# Generation     0.000
# Legendary      0.000
# dtype: float64

# %% [markdown]
# ## To drop irrelavant columns : type 2 and #

# %%
df.drop(columns=['Type 2','#'],inplace=True)

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# ## To read each column value

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
## to see all columns values using loop.
for i in df['Name']:
    
        
    print(i)
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# VenusaurMega Venusaur
# Charmander
# Charmeleon
# Charizard
# CharizardMega Charizard X
# CharizardMega Charizard Y
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# BeedrillMega Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# PidgeotMega Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran (Female)
# Nidorina
# Nidoqueen
# Nidoran (Male)
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# Arcanine
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# AlakazamMega Alakazam
# Machop
# Machoke
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# ...

# %% [markdown]
# ## To read multiple columns

# %%
df[['Name','Type 1','HP']]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %% [markdown]
# ## To read multiple columns with a certain rows

# %%
df[["Name",'HP']][400:411]
# Out:
#                         Name   HP
# 400                  Walrein  110
# 401                 Clamperl   35
# 402                  Huntail   55
# 403                 Gorebyss   55
# 404                Relicanth  100
# 405                  Luvdisc   43
# 406                    Bagon   45
# 407                  Shelgon   65
# 408                Salamence   95
# 409  SalamenceMega Salamence   95
# 410                   Beldum   40

# %% [markdown]
# ## OR

# %%
df.iloc[400:411,[0,1]]
# Out:
#                         Name  Type 1
# 400                  Walrein     Ice
# 401                 Clamperl   Water
# 402                  Huntail   Water
# 403                 Gorebyss   Water
# 404                Relicanth   Water
# 405                  Luvdisc   Water
# 406                    Bagon  Dragon
# 407                  Shelgon  Dragon
# 408                Salamence  Dragon
# 409  SalamenceMega Salamence  Dragon
# 410                   Beldum   Steel

# %% [markdown]
# ## To read particular  row

# %%
df.iloc[9]
# Out:
# Name          Squirtle
# Type 1           Water
# HP                  44
# Attack              48
# Defense             65
# Sp. Atk             50
# Sp. Def             64
# Speed               43
# Generation           1
# Legendary        False
# Name: 9, dtype: object

# %% [markdown]
# ## To read multiple rows will all columns

# %%
df.iloc[10:16]
# Out:
#                        Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 10                Wartortle  Water  59      63       80       65       80
# 11                Blastoise  Water  79      83      100       85      105
# 12  BlastoiseMega Blastoise  Water  79     103      120      135      115
# 13                 Caterpie    Bug  45      30       35       20       20
# 14                  Metapod    Bug  50      20       55       25       25
# 15               Butterfree    Bug  60      45       50       90       80
#
#     Speed  Generation  Legendary
# 10     58           1      False
# 11     78           1      False
# 12     78           1      False
# 13     45           1      False
# 14     30           1      False
# 15     70           1      False

# %%
df.iloc[10:16,2:5]
# Out:
#     HP  Attack  Defense
# 10  59      63       80
# 11  79      83      100
# 12  79     103      120
# 13  45      30       35
# 14  50      20       55
# 15  60      45       50

# %% [markdown]
# ## To read a specific name, i.e  Blastoise

# %%
df.iloc[11,0]
# Out:
# 'Blastoise'

# %%
# df.iloc[rows,column]
# df.iloc[30:46,0:2]
df.iloc[15,0][0]
# Out:
# 'B'

# %% [markdown]
# ## To iterate each rows of specific column

# %%
for i in df['Name']:
    print(i)
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# VenusaurMega Venusaur
# Charmander
# Charmeleon
# Charizard
# CharizardMega Charizard X
# CharizardMega Charizard Y
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# BeedrillMega Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# PidgeotMega Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran (Female)
# Nidorina
# Nidoqueen
# Nidoran (Male)
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# Arcanine
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# AlakazamMega Alakazam
# Machop
# Machoke
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# ...

# %% [markdown]
# ## To iterate multiple rows

# %%
for i,j in df.iterrows(): # here i is index and j is row data of each column
    print(i,"=----",j)      ## 
    #print(j[['Name','HP']])  ## fecthing specific columns
# Out:
# 0 =---- Name          Bulbasaur
# Type 1            Grass
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 =---- Name          Ivysaur
# Type 1          Grass
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 =---- Name          Venusaur
# Type 1           Grass
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# 3 =---- Name          VenusaurMega Venusaur
# Type 1                        Grass
# HP                               80
# ...

# %%
for i,j in df.iterrows(): # here i is index and j is row data of each column
    print(j[['Name','HP']])  ## fecthing specific columns
# Out:
# Name    Bulbasaur
# HP             45
# Name: 0, dtype: object
# Name    Ivysaur
# HP           60
# Name: 1, dtype: object
# Name    Venusaur
# HP            80
# Name: 2, dtype: object
# Name    VenusaurMega Venusaur
# HP                         80
# Name: 3, dtype: object
# Name    Charmander
# HP              39
# Name: 4, dtype: object
# Name    Charmeleon
# HP              58
# Name: 5, dtype: object
# Name    Charizard
# HP             78
# Name: 6, dtype: object
# Name    CharizardMega Charizard X
# HP                             78
# Name: 7, dtype: object
# Name    CharizardMega Charizard Y
# HP                             78
# Name: 8, dtype: object
# Name    Squirtle
# HP            44
# Name: 9, dtype: object
# Name    Wartortle
# HP             59
# Name: 10, dtype: object
# Name    Blastoise
# HP             79
# Name: 11, dtype: object
# Name    BlastoiseMega Blastoise
# HP                           79
# Name: 12, dtype: object
# Name    Caterpie
# HP            45
# ...

# %% [markdown]
# ## To see the unique values in a particular column.

# %%
df['Type 1'].unique()
#print(df['Type 1'].unique())
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ## To see the Counts of the category in a data

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df['Type 1'].mode()
# Out:
# 0    Water
# Name: Type 1, dtype: object

# %% [markdown]
# ## To find the specific information in a data or to apply a condition in a data

# %%
df[df['Type 1']=='Fire'] #it print only the data of Fire type1 pokemons
# Out:
#                           Name Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4                   Charmander   Fire   39      52       43       60       50
# 5                   Charmeleon   Fire   58      64       58       80       65
# 6                    Charizard   Fire   78      84       78      109       85
# 7    CharizardMega Charizard X   Fire   78     130      111      130       85
# 8    CharizardMega Charizard Y   Fire   78     104       78      159      115
# 42                      Vulpix   Fire   38      41       40       50       65
# 43                   Ninetales   Fire   73      76       75       81      100
# 63                   Growlithe   Fire   55      70       45       70       50
# 64                    Arcanine   Fire   90     110       80      100       80
# 83                      Ponyta   Fire   50      85       55       65       65
# 84                    Rapidash   Fire   65     100       70       80       80
# ...

# %% [markdown]
# ## it sort the values in ascending order

# %%
df.sort_values(by=['Name']) ## on the basis of Name
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 510                Abomasnow    Grass   90      92       75       92       85
# 511  AbomasnowMega Abomasnow    Grass   90     132      105      132      105
# 68                      Abra  Psychic   25      20       15      105       55
# 392                    Absol     Dark   65     130       60       75       60
# 393          AbsolMega Absol     Dark   65     150       60      115       60
# ..                       ...      ...  ...     ...      ...      ...      ...
# 632                  Zoroark     Dark   60     105       60      120       60
# 631                    Zorua     Dark   40      65       40       80       40
# 46                     Zubat   Poison   40      45       35       30       40
# 695                 Zweilous     Dark   72      85       70       65       70
# 794         Zygarde50% Forme   Dragon  108     100      121       81       95
#
# ...

# %%
df.sort_values(by=['Attack'])
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 488                  Happiny   Normal  100       5        5       15       65
# 121                  Chansey   Normal  250       5        5       35      105
# 230                  Shuckle      Bug   20      10      230       10      230
# 261                  Blissey   Normal  255      10       10       75      135
# 139                 Magikarp    Water   20      10       55       15       20
# ..                       ...      ...  ...     ...      ...      ...      ...
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
#
# ...

# %%
df['Attack'].min()
# Out:
# 5

# %% [markdown]
# ## it sort the values in descending order

# %%
df.sort_values(by=['Name'],ascending=False)
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 794         Zygarde50% Forme   Dragon  108     100      121       81       95
# 695                 Zweilous     Dark   72      85       70       65       70
# 46                     Zubat   Poison   40      45       35       30       40
# 631                    Zorua     Dark   40      65       40       80       40
# 632                  Zoroark     Dark   60     105       60      120       60
# ..                       ...      ...  ...     ...      ...      ...      ...
# 393          AbsolMega Absol     Dark   65     150       60      115       60
# 392                    Absol     Dark   65     130       60       75       60
# 68                      Abra  Psychic   25      20       15      105       55
# 511  AbomasnowMega Abomasnow    Grass   90     132      105      132      105
# 510                Abomasnow    Grass   90      92       75       92       85
#
# ...

# %%
df.sort_values(['Attack'],ascending=False)
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# ..                       ...      ...  ...     ...      ...      ...      ...
# 139                 Magikarp    Water   20      10       55       15       20
# 261                  Blissey   Normal  255      10       10       75      135
# 230                  Shuckle      Bug   20      10      230       10      230
# 121                  Chansey   Normal  250       5        5       35      105
# 488                  Happiny   Normal  100       5        5       15       65
#
# ...

# %% [markdown]
# ## when two columns name is given the it sort the values according to the first column

# %%
df.sort_values(["Attack","Name"])
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121                  Chansey   Normal  250       5        5       35      105
# 488                  Happiny   Normal  100       5        5       15       65
# 261                  Blissey   Normal  255      10       10       75      135
# 139                 Magikarp    Water   20      10       55       15       20
# 230                  Shuckle      Bug   20      10      230       10      230
# ..                       ...      ...  ...     ...      ...      ...      ...
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
#
# ...

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ## here it shows both column in descending order¶

# %%
df.sort_values(["Type 1","Attack"],ascending=[False,False])
# Out:
#                       Name Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 141  GyaradosMega Gyarados  Water   95     155      109       70      130
# 283  SwampertMega Swampert  Water  100     150      110       95      110
# 422    KyogrePrimal Kyogre  Water  100     150       90      180      160
# 349  SharpedoMega Sharpedo  Water   70     140       70      110       65
# 107                Kingler  Water   55     130      115       50       50
# ..                     ...    ...  ...     ...      ...      ...      ...
# 446              Kricketot    Bug   37      25       41       25       41
# 733                 Spewpa    Bug   45      22       60       27       30
# 14                 Metapod    Bug   50      20       55       25       25
# 179                 Ledyba    Bug   40      20       30       40       80
# 230                Shuckle    Bug   20      10      230       10      230
#
#      Speed  Generation  Legendary
# 141     81           1      False
# ...

# %%
df["Attack"].max()
# Out:
# 190

# %%
df[df["HP"]==df["HP"].max()]["Name"]
# Out:
# 261    Blissey
# Name: Name, dtype: object

# %% [markdown]
# ## here it shows both column in ascending order¶

# %%
df.sort_values(["Attack","Type 1"])
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121                  Chansey   Normal  250       5        5       35      105
# 488                  Happiny   Normal  100       5        5       15       65
# 230                  Shuckle      Bug   20      10      230       10      230
# 261                  Blissey   Normal  255      10       10       75      135
# 139                 Magikarp    Water   20      10       55       15       20
# ..                       ...      ...  ...     ...      ...      ...      ...
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
#
# ...

# %% [markdown]
# # Making changes to  the Data : Feature engineering:part of preprocessing)
# mostly used in ML where ml model accurcay matters it works in cycle.
#
# ### Feature engineering:
#
# ### Feature engineering refers to manipulation — addition, deletion, combination, mutation — of your data set to improve machine learning model training, leading to better performance and greater accuracy. Effective feature engineering is based on sound knowledge of the business problem and the available data sources.
#
#
# It involves:
#
# - Feature creation
# - feature transformation
# - feature selection
#
#  ### A common example of feature engineering is when your doctor uses your body mass index (BMI). BMI is calculated from both body weight and height, and serves as a surrogate for a characteristic that is very hard to accurately measure: the proportion of lean body mass.
#
#
# in house price  data one column is no of bedrroms, no of washrooms  and these columns are important to predict price but we need to consider only one column so we do feature engineering by constructing  new feature square feet area from both in such a way no information gets lost.

# %% [markdown]
# Here , we compute total`and drop those individuals with out losing information

# %%
#Here i am added the columns HP, Attack, Defense, Sp.Atk, Sp.Def,Speed and named it as Total
#first input is going to colon which means all rows everything[:]
#then count the column here HP is the 2 column upto 9 column speed[:,2:8]
#then define the axis along which you want to add here axis=1 means horizontally


df['Total']=df.iloc[:,2:8].sum(axis=1)
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary  Total
# ...

# %% [markdown]
#  ## Total sum of all stats that come after this, a general guide to how strong a Pokemon is

# %%
df["Total"].max()  ## strongest pokemon stats
# Out:
# 780

# %% [markdown]
# ## Who is strongest pokemon

# %%
df[df['Total']==780]["Name"]
# Out:
# 163      MewtwoMega Mewtwo X
# 164      MewtwoMega Mewtwo Y
# 426    RayquazaMega Rayquaza
# Name: Name, dtype: object

# %% [markdown]
# ## Arrange the column order

# %%
col=list(df.columns)
col
# Out:
# ['Name',
#  'Type 1',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
col[0:2]+[col[-1]]+col[2:10]  ## concatenation
# Out:
# ['Name',
#  'Type 1',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %%
# Arranging the columns

df=df[col[0:2]+[col[-1]]+col[2:10]]
df
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4               Charmander     Fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %% [markdown]
# ## Drop

# %%
pokemon=df.drop(columns=['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed'])

# %%
pokemon
# Out:
#                       Name   Type 1  Total  Generation  Legendary
# 0                Bulbasaur    Grass    318           1      False
# 1                  Ivysaur    Grass    405           1      False
# 2                 Venusaur    Grass    525           1      False
# 3    VenusaurMega Venusaur    Grass    625           1      False
# 4               Charmander     Fire    309           1      False
# ..                     ...      ...    ...         ...        ...
# 795                Diancie     Rock    600           6       True
# 796    DiancieMega Diancie     Rock    700           6       True
# 797    HoopaHoopa Confined  Psychic    600           6       True
# 798     HoopaHoopa Unbound  Psychic    680           6       True
# 799              Volcanion     Fire    600           6       True
#
# [800 rows x 5 columns]

# %% [markdown]
# ## Saving our transformed/cleaned Data (Exporting into desired format)

# %% [markdown]
# ## To save the dataset

# %%
pokemon.to_csv('updated_pokemon.csv',index=False) #here index=False to delete the extra indexes of csv format

# %%
# pokemon

# %%
##pokemon=pd.read_csv('updated_pokemon.csv')

# %% [markdown]
# ## Filtering of data Or Condition in data

# %%
df["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df[(df['Type 1']=="Grass") | (df['Legendary']==True)]
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 48                  Oddish    Grass    320  45      50       55       75
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[(df['Attack']==df['Attack'].min()) | (df['HP']==df['HP'].max())]
# Out:
#         Name  Type 1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 121  Chansey  Normal    450  250       5        5       35      105     50
# 261  Blissey  Normal    540  255      10       10       75      135     55
# 488  Happiny  Normal    220  100       5        5       15       65     30
#
#      Generation  Legendary
# 121           1      False
# 261           2      False
# 488           4      False

# %%
## or

# %%
df.iloc[np.where((df['Attack']==min(df['Attack'])) | (df['HP']==max(df['HP'])))]
# Out:
#         Name  Type 1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 121  Chansey  Normal    450  250       5        5       35      105     50
# 261  Blissey  Normal    540  255      10       10       75      135     55
# 488  Happiny  Normal    220  100       5        5       15       65     30
#
#      Generation  Legendary
# 121           1      False
# 261           2      False
# 488           4      False

# %%
# df[(df['Type 1']=="Dragon") & (df['Type 2']=='Fire')]

# %%
df[(df['Type 1']=="Grass") | (df['Legendary']==True)]
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 48                  Oddish    Grass    320  45      50       55       75
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[(df['Type 1']=='Grass') & (df['Generation']==6) & (df['Attack']>100)]
# Out:
#            Name Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 720  Chesnaught  Grass    530  88     107      122       74       75     64
#
#      Generation  Legendary
# 720           6      False

# %%
df[df['Name']=='Pikachu']#To find the any name in the data
# Out:
#        Name    Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 30  Pikachu  Electric    320  35      55       40       50       50     90
#
#     Generation  Legendary
# 30           1      False

# %%
df[df['Name']=='Raichu']
# Out:
#       Name    Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 31  Raichu  Electric    485  60      90       55       90       80    110
#
#     Generation  Legendary
# 31           1      False

# %%
# Here loc is for locating a string based column
#df.loc[df['Type 1']=='Fire','Type 1']='Flamer' #it chnages the Fire to Flamer in Type 1 column
#df

# %%
#df[df['Type 1']=='Flamer']

# %%
#df[(df['Type 1']=='Flamer') & (df['Generation']==6) & (df['Legendary']==True)]

# %% [markdown]
# ### Insights

# %%
df.dtypes
# Out:
# Name          object
# Type 1        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# ## How many types of pokemon exist in this catelog

# %%
len(df["Type 1"].unique())
# Out:
# 18

# %% [markdown]
# ####  Insight : 18 types of pokemon exist

# %% [markdown]
# ## Following are the categories

# %%
df["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ## Which pokemon type has highest and lowest instances

# %%
df["Type 1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# ####  water type pokemon is more and flying pokemon is less

# %% [markdown]
# ### How many legends pokemon

# %%
df["Legendary"].unique()
# Out:
# array([False,  True])

# %%
df["Legendary"].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %% [markdown]
# ## Upto which generation pokemon exits

# %%
df["Generation"].unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %% [markdown]
# ## Which generation has more pokemon

# %%
df["Generation"].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %% [markdown]
# ##  Which category of  pokemon  is strongest and weekest

# %%
df[df["Total"]==df["Total"].max()]["Type 1"]
# Out:
# 163    Psychic
# 164    Psychic
# 426     Dragon
# Name: Type 1, dtype: object

# %%
df[df["Total"]==df["Total"].min()]["Type 1"]
# Out:
# 206    Grass
# Name: Type 1, dtype: object

# %%
#df.sort_values(by="Total",ascending=False)

# %%
#df.sort_values(by="Total",ascending=False).tail()  ## weekest

# %% [markdown]
# ### Strongest pokemon of types : Dragon and Psychic type
# ### weekest :  Grass type

# %% [markdown]
# ## Find top 5 pokemon based on total

# %%
df.sort_values(by="Total",ascending=False).head(5)
# Out:
#                       Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 426  RayquazaMega Rayquaza   Dragon    780  105     180      100      180
# 164    MewtwoMega Mewtwo Y  Psychic    780  106     150       70      194
# 163    MewtwoMega Mewtwo X  Psychic    780  106     190      100      154
# 422    KyogrePrimal Kyogre    Water    770  100     150       90      180
# 424  GroudonPrimal Groudon   Ground    770  100     180      160      150
#
#      Sp. Def  Speed  Generation  Legendary
# 426      100    115           3       True
# 164      120    140           1       True
# 163      100    130           1       True
# 422      160     90           3       True
# 424       90     90           3       True

# %% [markdown]
# ## Find the maximum,min and average stats of each category of pokemon

# %%
df.groupby(['Type 1'])['Total'].agg(["max","mean","min"])
# Out:
#           max        mean  min
# Type 1
# Bug       600  378.927536  194
# Dark      680  445.741935  220
# Dragon    780  550.531250  300
# Electric  610  443.409091  205
# Fairy     680  413.176471  218
# Fighting  625  416.444444  210
# Fire      680  458.076923  250
# Flying    580  485.000000  245
# Ghost     680  439.562500  275
# Grass     630  421.142857  180
# Ground    770  437.500000  265
# Ice       580  433.458333  250
# Normal    720  401.683673  190
# Poison    535  399.142857  245
# Psychic   780  475.947368  198
# Rock      700  453.750000  280
# Steel     700  487.703704  300
# Water     770  430.455357  200

# %%
x=df.groupby(['Type 1'])['Total'].agg(["max","mean","min"])
x.sort_values(by="mean",ascending=False)
## or df.groupby(['Type 1'])['Total'].agg(["max","mean","min"]).sort_values(by="mean")
# Out:
#           max        mean  min
# Type 1
# Dragon    780  550.531250  300
# Steel     700  487.703704  300
# Flying    580  485.000000  245
# Psychic   780  475.947368  198
# Fire      680  458.076923  250
# Rock      700  453.750000  280
# Dark      680  445.741935  220
# Electric  610  443.409091  205
# Ghost     680  439.562500  275
# Ground    770  437.500000  265
# Ice       580  433.458333  250
# Water     770  430.455357  200
# Grass     630  421.142857  180
# Fighting  625  416.444444  210
# Fairy     680  413.176471  218
# Normal    720  401.683673  190
# Poison    535  399.142857  245
# Bug       600  378.927536  194

# %% [markdown]
# ## Dragon type of pokemon is powerful  and Bug is weekest based on average stats points,

# %% [markdown]
# ### details of Dragon type pokemon

# %%
df[df["Type 1"]=="Dragon"]
# Out:
#                         Name  Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 159                  Dratini  Dragon    300   41      64       45       50
# 160                Dragonair  Dragon    420   61      84       65       70
# 161                Dragonite  Dragon    600   91     134       95      100
# 365                  Altaria  Dragon    490   75      70       90       70
# 366      AltariaMega Altaria  Dragon    590   75     110      110      110
# 406                    Bagon  Dragon    300   45      75       60       40
# 407                  Shelgon  Dragon    420   65      95      100       60
# 408                Salamence  Dragon    600   95     135       80      110
# 409  SalamenceMega Salamence  Dragon    700   95     145      130      120
# 417                   Latias  Dragon    600   80      80       90      110
# 418        LatiasMega Latias  Dragon    700   80     100      120      140
# ...

# %%
df[(df["Type 1"]=="Dragon") & (df["Total"]==780)]
# Out:
#                       Name  Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 426  RayquazaMega Rayquaza  Dragon    780  105     180      100      180
#
#      Sp. Def  Speed  Generation  Legendary
# 426      100    115           3       True

# %% [markdown]
# ## Which pokeman whose total points is max and min

# %%
df[df['Total']==df['Total'].max()]
# Out:
#                       Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 163    MewtwoMega Mewtwo X  Psychic    780  106     190      100      154
# 164    MewtwoMega Mewtwo Y  Psychic    780  106     150       70      194
# 426  RayquazaMega Rayquaza   Dragon    780  105     180      100      180
#
#      Sp. Def  Speed  Generation  Legendary
# 163      100    130           1       True
# 164      120    140           1       True
# 426      100    115           3       True

# %%
df[df['Total']==df['Total'].min()]
# Out:
#         Name Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 206  Sunkern  Grass    180  30      30       30       30       30     30
#
#      Generation  Legendary
# 206           2      False

# %% [markdown]
# ## Find the average,max and min total stats of each type 1 along with pokemon names

# %%
df.groupby(['Type 1','Name'])['Total'].agg(['mean','max','min'])
# Out:
#                                mean  max  min
# Type 1 Name
# Bug    Accelgor               495.0  495  495
#        Ariados                390.0  390  390
#        Beautifly              395.0  395  395
#        Beedrill               395.0  395  395
#        BeedrillMega Beedrill  495.0  495  495
# ...                             ...  ...  ...
# Water  Wailord                500.0  500  500
#        Wartortle              405.0  405  405
#        Whiscash               468.0  468  468
#        Wingull                270.0  270  270
#        Wooper                 210.0  210  210
#
# [800 rows x 3 columns]

# %% [markdown]
# ### Which generation' pokemon is strongest

# %%
df.groupby(['Generation'])['Total'].agg(['mean','max','min']).sort_values(by="max",ascending=False)
# Out:
#                   mean  max  min
# Generation
# 1           426.813253  780  195
# 3           436.225000  780  190
# 4           459.016529  720  194
# 2           418.283019  700  180
# 5           434.987879  700  255
# 6           436.378049  700  200

# %% [markdown]
# ### of Which generation which type of pokemon is strongest

# %%
df.groupby(['Generation','Type 1'])['Total'].agg(['mean','max','min'])
# Out:
#                            mean  max  min
# Generation Type 1
# 1          Bug       366.428571  600  195
#            Dragon    440.000000  600  300
#            Electric  444.444444  580  320
#            Fairy     403.000000  483  323
#            Fighting  412.142857  505  305
# ...                         ...  ...  ...
# 6          Poison    407.000000  494  320
#            Psychic   513.400000  680  355
#            Rock      485.777778  700  306
#            Steel     456.600000  520  325
#            Water     415.800000  530  314
#
# [98 rows x 3 columns]

# %% [markdown]
# ## Top 5 pokemon based on hp

# %%
df.sort_values(by="HP",ascending=False)[["Name","Type 1","Generation","Legendary","HP"]].head(5)
# Out:
#           Name   Type 1  Generation  Legendary   HP
# 261    Blissey   Normal           2      False  255
# 121    Chansey   Normal           1      False  250
# 217  Wobbuffet  Psychic           2      False  190
# 351    Wailord    Water           3      False  170
# 655  Alomomola    Water           5      False  165

# %% [markdown]
# ## Normal type has highest HP

# %% [markdown]
# ## Find max,min and average HP  of each type

# %%
df.groupby(["Type 1"])["HP"].agg(["max","min","mean"]).sort_values(by="max",ascending=False)
# Out:
#           max  min       mean
# Type 1
# Normal    255   30  77.275510
# Psychic   190   20  70.631579
# Water     170   20  72.062500
# Ghost     150   20  64.437500
# Fighting  144   30  69.851852
# Dark      126   35  66.806452
# Fairy     126   35  74.117647
# Dragon    125   41  83.312500
# Rock      123   30  65.363636
# Grass     123   30  67.271429
# Ground    115   10  73.781250
# Fire      115   38  69.903846
# Ice       110   36  72.000000
# Poison    105   35  67.250000
# Steel     100   40  65.222222
# Electric   90   20  59.795455
# Bug        86    1  56.884058
# Flying     85   40  70.750000

# %% [markdown]
# ### normal type has highest hp
# ### flyinh type has lowest hp

# %% [markdown]
# ## Top 5 pokemon based on Attack

# %%
df.sort_values(by="Attack",ascending=False)[["Name","Type 1","Generation","Legendary","Attack"]].head(5)
# Out:
#                         Name   Type 1  Generation  Legendary  Attack
# 163      MewtwoMega Mewtwo X  Psychic           1       True     190
# 232  HeracrossMega Heracross      Bug           2      False     185
# 424    GroudonPrimal Groudon   Ground           3       True     180
# 426    RayquazaMega Rayquaza   Dragon           3       True     180
# 429       DeoxysAttack Forme  Psychic           3       True     180

# %% [markdown]
# ## Find max,min and average attack of each Type

# %%
df.groupby(["Type 1"])["Attack"].agg(["max","min","mean"]).sort_values(by="max",ascending=False)
# Out:
#           max  min        mean
# Type 1
# Psychic   190   20   71.456140
# Bug       185   10   70.971014
# Dragon    180   50  112.125000
# Ground    180   40   95.750000
# Ghost     165   30   73.781250
# Rock      165   40   92.863636
# Normal    160    5   73.469388
# Fire      160   30   84.769231
# Water     155   10   74.151786
# Dark      150   50   88.387097
# Steel     150   24   92.703704
# Fighting  145   35   96.777778
# Grass     132   27   73.214286
# Fairy     131   20   61.529412
# Ice       130   30   72.750000
# Electric  123   30   69.090909
# Flying    115   30   78.750000
# Poison    106   43   74.678571

# %% [markdown]
# ## psycic has strongest attck
# ## Poison has weekest attack.

# %% [markdown]
# ## Top 5 pokemon based on Speed

# %%
df.sort_values(by="Speed",ascending=False)[["Name","Type 1","Generation","Legendary","Speed"]].head(5)
# Out:
#                           Name   Type 1  Generation  Legendary  Speed
# 431          DeoxysSpeed Forme  Psychic           3       True    180
# 315                    Ninjask      Bug           3      False    160
# 428         DeoxysNormal Forme  Psychic           3       True    150
# 154  AerodactylMega Aerodactyl     Rock           1      False    150
# 71       AlakazamMega Alakazam  Psychic           1      False    150

# %% [markdown]
# ## Findmax,min and average speed of each type

# %%
df.groupby(["Type 1"])["Speed"].agg(["max","min","mean"]).sort_values(by="max",ascending=False)
# Out:
#           max  min        mean
# Type 1
# Psychic   180   20   81.491228
# Bug       160    5   61.681159
# Rock      150   10   55.909091
# Grass     145   10   61.928571
# Electric  140   35   84.500000
# Normal    135    5   71.551020
# Ghost     130   20   64.343750
# Poison    130   25   63.571429
# Fire      126   20   74.442308
# Dark      125   20   76.161290
# Flying    123   55  102.500000
# Water     122   15   65.964286
# Ground    120   10   63.906250
# Dragon    120   40   83.031250
# Fighting  118   25   66.074074
# Ice       110   25   63.458333
# Steel     110   23   55.259259
# Fairy      99   15   48.588235

# %% [markdown]
# ## psycic has high spped
# ## fairy has low speed

# %% [markdown]
# ## Top 5 pokemon based on Defence

# %%
df.sort_values(by="Defense",ascending=False)[["Name","Type 1","Generation","Legendary","Defense"]].head(5)
# Out:
#                     Name Type 1  Generation  Legendary  Defense
# 230              Shuckle    Bug           2      False      230
# 224  SteelixMega Steelix  Steel           2      False      230
# 333    AggronMega Aggron  Steel           3      False      230
# 223              Steelix  Steel           2      False      200
# 414             Regirock   Rock           3       True      200

# %% [markdown]
# ## Find max,min and average defense of each type

# %%
df.groupby(["Type 1"])["Defense"].agg(["max","min","mean"]).sort_values(by="max",ascending=False)
# Out:
#           max  min        mean
# Type 1
# Bug       230   30   70.724638
# Steel     230   50  126.370370
# Rock      200   40  100.795455
# Ice       184   15   71.416667
# Water     180   20   72.946429
# Ground    160   25   84.843750
# Psychic   160   15   67.684211
# Ghost     145   30   81.187500
# Fire      140   37   67.769231
# Grass     131   30   70.800000
# Dragon    130   35   86.375000
# Normal    126    5   59.846939
# Dark      125   30   70.225806
# Poison    120   35   68.821429
# Electric  115   15   66.295455
# Fighting   95   30   65.925926
# Fairy      95   28   65.705882
# Flying     80   35   66.250000

# %% [markdown]
# ## bug has high defense power
# ## flying has low defense power

# %% [markdown]
# ## Top 5 pokemon based on spl. attack.

# %%
df.sort_values(by="Sp. Atk",ascending=False)[["Name","Type 1","Generation","Legendary","Sp. Atk"]].head(5)
# Out:
#                       Name   Type 1  Generation  Legendary  Sp. Atk
# 164    MewtwoMega Mewtwo Y  Psychic           1       True      194
# 422    KyogrePrimal Kyogre    Water           3       True      180
# 429     DeoxysAttack Forme  Psychic           3       True      180
# 426  RayquazaMega Rayquaza   Dragon           3       True      180
# 71   AlakazamMega Alakazam  Psychic           1      False      175

# %% [markdown]
# ## Find max,min and average spl.attack of each type

# %%
df.groupby(["Type 1"])["Sp. Atk"].agg(["max","min","mean"]).sort_values(by="mean",ascending=False)
# Out:
#           max  min       mean
# Type 1
# Psychic   194   23  98.403509
# Dragon    180   30  96.843750
# Flying    125   45  94.250000
# Electric  165   35  90.022727
# Fire      159   15  88.980769
# Ghost     170   30  79.343750
# Fairy     131   40  78.529412
# Ice       130   30  77.541667
# Grass     145   24  77.500000
# Water     180   10  74.812500
# Dark      140   30  74.645161
# Steel     150   24  67.518519
# Rock      160   10  63.340909
# Poison    100   30  60.428571
# Ground    150   20  56.468750
# Normal    135   15  55.816327
# Bug       135   10  53.869565
# Fighting  140   20  53.111111

# %% [markdown]
# ## Top 5 pokemon based on spl. defence.

# %%
df.sort_values(by="Sp. Def",ascending=False)[["Name","Type 1","Generation","Legendary","Sp. Def"]].head(5)
# Out:
#                     Name   Type 1  Generation  Legendary  Sp. Def
# 230              Shuckle      Bug           2      False      230
# 415               Regice      Ice           3       True      200
# 430  DeoxysDefense Forme  Psychic           3       True      160
# 422  KyogrePrimal Kyogre    Water           3       True      160
# 270                Ho-oh     Fire           2       True      154

# %% [markdown]
# ## Find max,min and average spl.defense of each type

# %%
df.groupby(["Type 1"])["Sp. Def"].agg(["max","min","mean"]).sort_values(by="mean",ascending=False)
# Out:
#           max  min       mean
# Type 1
# Dragon    150   30  88.843750
# Psychic   160   20  86.280702
# Fairy     154   40  84.705882
# Steel     150   37  80.629630
# Ghost     135   33  76.468750
# Ice       200   30  76.291667
# Rock      150   25  75.477273
# Electric  110   32  73.704545
# Flying     90   40  72.500000
# Fire      154   40  72.211538
# Water     160   20  70.517857
# Grass     129   30  70.428571
# Dark      130   30  69.516129
# Bug       230   20  64.797101
# Fighting  110   30  64.703704
# Poison    123   40  64.392857
# Normal    135   20  63.724490
# Ground    120   30  62.750000
